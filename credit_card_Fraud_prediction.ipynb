# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('creditcard_downsampled.csv')
credit_card_data.head()
# Out:
#        Time         V1        V2         V3        V4         V5        V6  \
# 0   41505.0 -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 1   44261.0   0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 2   35484.0   1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 3  167123.0  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 4  168473.0   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -16.701694  7.517344 -8.507059  ...  1.190739 -1.127670 -2.358579  0.673461
# 1  -0.524379  0.224060  0.899746  ... -0.213436 -0.942525 -0.526819 -1.156992
# 2  -0.712567  0.002299 -0.971747  ...  0.102398  0.168269 -0.166639 -0.810250
# 3   0.276990  0.586025 -0.484715  ...  0.358932  0.873663 -0.178642 -0.017171
# 4   0.043241 -0.160746  0.363241  ... -0.238644 -0.616400  0.347045  0.061561
#
# ...

# %%
credit_card_data.sample()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 24081  42950.0  1.397725 -0.898465  0.457864 -2.080594 -1.595488 -1.243762
#
#              V7        V8        V9  ...       V21       V22      V23  \
# 24081 -0.770941 -0.196073  0.506981  ... -0.210408 -0.028599 -0.03922
#
#             V24       V25       V26       V27       V28  Amount  Class
# 24081  0.404516  0.407665  0.088761  0.043117  0.024633   15.21      0
#
# [1 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34177 entries, 0 to 34176
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    34177 non-null  float64
#  1   V1      34177 non-null  float64
#  2   V2      34177 non-null  float64
#  3   V3      34177 non-null  float64
#  4   V4      34177 non-null  float64
#  5   V5      34177 non-null  float64
#  6   V6      34177 non-null  float64
#  7   V7      34177 non-null  float64
#  8   V8      34177 non-null  float64
#  9   V9      34177 non-null  float64
#  10  V10     34177 non-null  float64
#  11  V11     34177 non-null  float64
#  12  V12     34177 non-null  float64
#  13  V13     34177 non-null  float64
#  14  V14     34177 non-null  float64
#  15  V15     34177 non-null  float64
#  16  V16     34177 non-null  float64
#  17  V17     34177 non-null  float64
#  18  V18     34177 non-null  float64
#  19  V19     34177 non-null  float64
#  20  V20     34177 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    34119
# 1       58
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data['Class']==1]

# %%
fraud['Class']
# Out:
# 0        1
# 565      1
# 3025     1
# 3228     1
# 4178     1
# 4640     1
# 5100     1
# 5756     1
# 6054     1
# 6368     1
# 7011     1
# 7846     1
# 8090     1
# 8379     1
# 8456     1
# 9203     1
# 10279    1
# 10634    1
# 11066    1
# 11245    1
# 13509    1
# 16473    1
# 16564    1
# 16592    1
# 16839    1
# 17345    1
# 17388    1
# 18130    1
# 18544    1
# 18785    1
# 18861    1
# 19281    1
# 19442    1
# 19821    1
# 20031    1
# 21199    1
# 22412    1
# 22588    1
# 22718    1
# 22797    1
# 23380    1
# 24197    1
# 25774    1
# 25903    1
# 27670    1
# 27885    1
# 28803    1
# 30129    1
# 30923    1
# 30971    1
# 31055    1
# 31337    1
# 31575    1
# 32102    1
# 32656    1
# 32949    1
# 33127    1
# 34064    1
# Name: Class, dtype: int64

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    34119.000000
# mean        87.596594
# std        225.333821
# min          0.000000
# 25%          5.860000
# 50%         22.000000
# 75%         77.120000
# max       5239.500000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      58.000000
# mean      196.743103
# std       358.516774
# min         0.000000
# 25%         1.000000
# 50%         9.840000
# 75%       142.687500
# max      1504.930000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94868.352062  0.002335 -0.008049  0.016550 -0.003917  0.003554
# 1      85295.741379 -5.445456  3.215654 -7.104626  4.599785 -3.356590
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002478  0.002574 -0.004877  0.000911  ...  0.001472 -0.007064
# 1     -1.128131 -5.804209 -0.294965 -2.769350  ...  0.585052  0.448090
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.006633 -0.001692 -0.001944  0.004325  0.003611  0.003133 -0.002925
# 1      0.196192  0.144790 -0.102447 -0.030327  0.015814  0.013081 -0.012013
#
#            Amount
# Class
# 0       87.596594
# 1      196.743103
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)

# %%
new_df
# Out:
#            Time         V1         V2         V3         V4         V5  \
# 14976   62395.0  -0.514037   0.953548   1.639592  -0.149570   0.061661
# 27933  162842.0   1.800719  -0.054845  -1.948306   1.368605   0.421907
# 33197  164986.0  -0.260435   0.574557   0.538932  -0.200957  -0.459723
# 5928    31697.0  -1.303505   0.305980   1.735987  -2.893345  -0.368520
# 19964  121557.0   2.007350  -0.115175  -1.096012   0.432498  -0.129556
# ...         ...        ...        ...        ...        ...        ...
# 32102  154278.0  -1.600211  -3.488130  -6.459303   3.246816  -1.614608
# 32656  102114.0 -28.255053  21.467203 -26.871339  11.737436 -17.999630
# 32949  102669.0  -5.603690   5.222193  -7.516830   8.117724  -2.756858
# 33127  141565.0   0.114965   0.766762  -0.494132   0.116772   0.868169
# 34064   53031.0   0.206075   1.387360  -1.045287   4.228686  -1.647549
#
#              V6         V7         V8         V9  ...        V21       V22  \
# ...

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1     58
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95361.837398 -0.021203 -0.039347  0.015218  0.008594  0.054947
# 1      85295.741379 -5.445456  3.215654 -7.104626  4.599785 -3.356590
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.079608 -0.059579 -0.116898 -0.020133  ...  0.081292 -0.065697
# 1     -1.128131 -5.804209 -0.294965 -2.769350  ...  0.585052  0.448090
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.017552 -0.037896  0.017398 -0.019702  0.005413 -0.049102 -0.031033
# 1      0.196192  0.144790 -0.102447 -0.030327  0.015814  0.013081 -0.012013
#
#            Amount
# Class
# 0       85.724675
# 1      196.743103
#
# [2 rows x 30 columns]

# %%
X = new_df.drop(columns='Class')
Y = new_df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# # Model Training
# Logistic Regression

# %%
model=LogisticRegression()

# %%
 # training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9727272727272728
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.990909090909091

# %% [markdown]
# # input

# %%
# Create a sample input for prediction.
# Ensure the column names and order match the training data (X).
# For demonstration, I'm using placeholder values.
# You should replace these with the actual data you want to predict on.
sample_input_data = {
    'Time': [1000.0],
    'V1': [0.1],
    'V2': [0.2],
    'V3': [0.3],
    'V4': [0.4],
    'V5': [0.5],
    'V6': [0.6],
    'V7': [0.7],
    'V8': [0.8],
    'V9': [0.9],
    'V10': [1.0],
    'V11': [1.1],
    'V12': [1.2],
    'V13': [1.3],
    'V14': [1.4],
    'V15': [1.5],
    'V16': [1.6],
    'V17': [1.7],
    'V18': [1.8],
    'V19': [1.9],
    'V20': [2.0],
    'V21': [2.1],
    'V22': [2.2],
    'V23': [2.3],
    'V24': [2.4],
    'V25': [2.5],
    'V26': [2.6],
    'V27': [2.7],
    'V28': [2.8],
    'Amount': [100.0]
}
sample_input_df = pd.DataFrame(sample_input_data)

# %%
# Make a prediction using the trained model
prediction = model.predict(sample_input_df)

# Print the prediction
if prediction[0] == 0:
    print('The transaction is predicted to be: Legit')
else:
    print('The transaction is predicted to be: Fraudulent')

print(f'Raw prediction (0 for Legit, 1 for Fraud): {prediction[0]}')
# Out:
# The transaction is predicted to be: Legit
# Raw prediction (0 for Legit, 1 for Fraud): 0
